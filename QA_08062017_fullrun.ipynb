# %% [markdown]
# ## Question Answering using Deep Learning

# %%
import sys
import re
import tarfile
from functools import reduce
from itertools import chain
import os
from six.moves import urllib

import numpy as np
import tensorflow as tf
from tensorflow.python.ops import variable_scope as vs

# %%
BABI_DATASET_URL = 'https://s3.amazonaws.com/text-datasets/babi_tasks_1-20_v1-2.tar.gz'
DATASET_PATH = './babi'

# %%
def fetch_data(dataset_download_url=BABI_DATASET_URL, save_dataset_path=DATASET_PATH): 
    if not os.path.isdir(save_dataset_path):
        os.makedirs(save_dataset_path)
    tar_file_path = os.path.join(save_dataset_path, 'babi_tasks_data_1_20_v1.2.tar.gz')
    urllib.request.urlretrieve(dataset_download_url, tar_file_path)
    babi_tar_file = tarfile.open(tar_file_path)
    babi_tar_file.extractall(path=DATASET_PATH)
    babi_tar_file.close()

# %%
fetch_data(dataset_download_url=BABI_DATASET_URL, save_dataset_path=DATASET_PATH)

# %%
class Config:
    """Holds model hyperparams and data information.
    Model objects are passed a Config() object at instantiation.
    """

    def __init__(self):
        pass

    batch_size = 32
    embed_size = 50
    hidden_size = 50
    #max_epochs = 5000
    max_epochs = 500
    dropout = 0.7
    lr = 0.8
    L2 = 0.001

    vocab_size = None
    num_steps_sentence = None
    num_steps_story = None
    num_steps_question = None

# %%
class RNN_Model:
    def __init__(self, config):
        self.config = config    
        self.add_placeholders()
        self.inputs_story, self.inputs_question = self.add_embedding()
        self.story_question_state = self.add_basic_model(self.inputs_story, self.inputs_question)

        self.output = self.add_projection(self.story_question_state)

        with tf.name_scope('Accuracy'):
            self.predictions = tf.nn.softmax(self.output)
            self.one_hot_prediction = tf.argmax(self.predictions, 1)
            correct_prediction = tf.equal(tf.argmax(self.labels_placeholder, 1), self.one_hot_prediction)
            self.correct_predictions = tf.reduce_sum(tf.cast(correct_prediction, 'int32'))

        with tf.name_scope('Loss'):
            loss, lossL2 = self.add_loss_op(self.output)
            self.calculate_loss = loss + self.config.L2 * lossL2
        with tf.name_scope('Train'):
            self.train_step = self.add_training_op(self.calculate_loss)

    
    def add_placeholders(self):
        """Generate placeholder variables to represent the input tensors
        """
        self.input_story_placeholder = tf.placeholder(
            tf.int32, shape=[None, self.config.num_steps_story, self.config.num_steps_sentence], name='InputStory')
        self.input_question_placeholder = tf.placeholder(
            tf.int32, shape=[None, self.config.num_steps_question], name='InputQuestion')
        self.labels_placeholder = tf.placeholder(
            tf.int32, shape=[None, self.config.vocab_size], name='Target')
        self.X_length = tf.placeholder(tf.int32, shape=[None], name='X_length')
        self.dropout_placeholder = tf.placeholder(tf.float32, name='Dropout')

        
    def add_embedding(self):
        """Add embedding layer.

        Returns:
          inputs: List of length num_steps, each of whose elements should be
                  a tensor of shape (batch_size, embed_size).
        """
        embedding = tf.get_variable('Embedding', [self.config.vocab_size, self.config.embed_size], trainable=True,
                                    initializer=tf.contrib.layers.xavier_initializer())
        inputs_story = tf.nn.embedding_lookup(embedding, self.input_story_placeholder)
        inputs_question = tf.nn.embedding_lookup(embedding, self.input_question_placeholder)

        # Position Encoding
        inputs_question = tf.expand_dims(inputs_question, 1)
        encoded_story = self.get_position_encoding(inputs_story, self.config.num_steps_sentence, 'StoryEncoding')
        encoded_query = self.get_position_encoding(inputs_question, self.config.num_steps_question, 'QueryEncoding')
        encoded_query = tf.tile(encoded_query, tf.stack([1, self.config.num_steps_story, 1]), name=None)

        return encoded_story, encoded_query

    def get_position_encoding(self, embedding, max_length, scope=None):
        """
        Module described in [End-To-End Memory Networks](https://arxiv.org/abs/1502.01852) as Position Encoding (PE).
        The mask allows the ordering of words in a sentence to affect the encoding.
        """
        J, d = max_length, self.config.embed_size
        l = np.zeros((J, d))
        with tf.variable_scope(scope, 'PE'):
            for j in range(J):
                for k in range(d):
                    l[j, k] = (1. - (j + 1.) / J) - ((k + 1.) / d) * (1. - 2. * (j + 1.) / J)
            self.l = tf.constant(l, shape=[J, d])
            m = tf.reduce_sum(embedding * tf.cast(self.l, tf.float32), 2, name='m')
        return m

    def add_projection(self, rnn_output):
        """Adds a projection layer.

        The projection layer transforms the hidden representation to a distribution
        over the vocabulary.

        Args:
          rnn_output: List of length num_steps, each of whose elements should be
                       a tensor of shape (batch_size, embed_size).
        Returns:
          outputs: List of length num_steps, each a tensor of shape
                   (batch_size, len(vocab))
        """
        with tf.variable_scope('Projection'):
            U = tf.get_variable('Weights',
                                [self.config.hidden_size, self.config.vocab_size], trainable=True,
                                initializer=tf.contrib.layers.xavier_initializer())
            b = tf.get_variable('Bias', [self.config.vocab_size])
            outputs = tf.matmul(rnn_output, U) + b

        return outputs

    def add_loss_op(self, output):
        """Adds loss ops to the computational graph.

        Args:
          output: A tensor of shape (None, self.vocab)
        Returns:
          loss: A 0-d tensor (scalar)
        """
        var = tf.trainable_variables()
        cross_entropy = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(logits=output, labels=self.labels_placeholder))
        tf.add_to_collection('total_loss', cross_entropy)
        loss = tf.add_n(tf.get_collection('total_loss'))
        lossL2 = tf.add_n([tf.nn.l2_loss(v) for v in var if 'Bias' not in v.name])

        return loss, lossL2

    def add_training_op(self, loss):
        """Sets up the training Ops.
        Args:
          loss: Loss tensor, from cross_entropy_loss.
        Returns:
          train_op: The Op for training.
        """
        optimizer = tf.train.AdagradOptimizer(self.config.lr)
        train_op = optimizer.minimize(loss)

        return train_op
    
    def add_basic_model(self, inputs_story, inputs_question):
        basic_lstm = tf.contrib.rnn.BasicLSTMCell(num_units=self.config.hidden_size)
        basic_lstm = tf.contrib.rnn.DropoutWrapper(basic_lstm, input_keep_prob=self.dropout_placeholder,
                                            output_keep_prob=self.dropout_placeholder)

        with tf.variable_scope('basic_cell') as scope:
            #a, b = basic_dynamic_rnn(basic_lstm, [inputs_story, inputs_question],
            #                                sequence_length=self.X_length,
            #                                dtype=tf.float32)
            a, b = basic_dynamic_rnn(basic_lstm, [inputs_story, inputs_question],
                                            sequence_length=self.X_length,
                                            dtype=tf.float32)

        return tf.reduce_sum(b, 0)
        
    

    def predict(self, session, data):
        input_story, input_question, input_labels, X_length = data
        config = self.config
        dp = 1

        n_data = len(input_story)
        batches = zip(range(0, n_data - config.batch_size, config.batch_size),
                      range(config.batch_size, n_data, config.batch_size))
        batches = [(start, end) for start, end in batches]
        total_correct_examples = 0
        total_processed_examples = 0
        for step, (start, end) in enumerate(batches):
            feed = {self.input_story_placeholder: input_story[start:end],
                    self.input_question_placeholder: input_question[start:end],
                    self.labels_placeholder: input_labels[start:end],
                    self.dropout_placeholder: dp,
                    self.X_length: X_length[start:end]}
            total_correct = session.run(self.correct_predictions, feed_dict=feed)
            total_processed_examples += end - start
            total_correct_examples += total_correct
        acc = total_correct_examples / float(total_processed_examples)

        return acc

    
    def run_epoch(self, session, data, train_op=None, verbose=10):
            input_story, input_question, input_labels, X_length = data
            config = self.config
            dp = config.dropout

            if not train_op:
                train_op = tf.no_op()
                dp = 1

            n_data = len(input_story)
            batches = zip(range(0, n_data - config.batch_size, config.batch_size),
                          range(config.batch_size, n_data, config.batch_size))
            batches = [(start, end) for start, end in batches]
            np.random.shuffle(batches)
            n_val = int(len(batches) * 0.1)
            batches_train = batches[:-n_val]
            batches_val = batches[-n_val:]

            total_loss = []
            total_correct_examples = 0
            total_processed_examples = 0
            total_steps = len(batches_train)
            for step, (start, end) in enumerate(batches_train):
                feed = {self.input_story_placeholder: input_story[start:end],
                        self.input_question_placeholder: input_question[start:end],
                        self.labels_placeholder: input_labels[start:end],
                        self.dropout_placeholder: dp,
                        self.X_length: X_length[start:end]}
                loss, total_correct, _ = session.run(
                    [self.calculate_loss, self.correct_predictions, train_op],
                    feed_dict=feed)
                total_processed_examples += end - start
                total_correct_examples += total_correct
                total_loss.append(loss)
                if verbose and step % verbose == 0:
                    sys.stdout.write('\r{} / {} : loss = {}'.format(
                        step, total_steps, np.mean(total_loss)))
                    sys.stdout.flush()
                if verbose:
                    sys.stdout.write('\r')
            train_acc = total_correct_examples / float(total_processed_examples)

            Story = []
            Question = []
            Answer = []
            Prediction = []
            total_correct_examples = 0
            total_processed_examples = 0
            for step, (start, end) in enumerate(batches_val):
                feed = {self.input_story_placeholder: input_story[start:end],
                        self.input_question_placeholder: input_question[start:end],
                        self.labels_placeholder: input_labels[start:end],
                        self.dropout_placeholder: 1,
                        self.X_length: X_length[start:end]}
                total_correct, prediction = session.run([self.correct_predictions, self.one_hot_prediction], feed_dict=feed)
                total_processed_examples += end - start
                total_correct_examples += total_correct

                Story.append(input_story[start:end])
                Question.append(input_question[start:end])
                Answer.append(input_labels[start:end])
                Prediction.append(prediction)

            val_acc = total_correct_examples / float(total_processed_examples)

            return np.mean(total_loss), train_acc, val_acc, Story, Question, Answer, Prediction

# %%
def basic_dynamic_rnn(cell_fw, inputs, sequence_length=None,
                                     initial_state_fw=None, 
                                     dtype=None, parallel_iterations=None,
                                     swap_memory=False, time_major=False, scope=None):
    with vs.variable_scope(scope or "unidirectional_rnn"):
        
        with vs.variable_scope("fw") as fw_scope:
            inputs_concat = tf.concat(inputs, 1)
            output_fw, output_state_fw = tf.nn.dynamic_rnn(
                cell=cell_fw, inputs=inputs_concat, sequence_length=sequence_length,
                initial_state=initial_state_fw, dtype=dtype
                )
            
    return output_fw, output_state_fw

# %% [markdown]
# ## Data Preprocessing

# %%
def reset_graph(seed=3242):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)


def get_data(task_path):
    train = get_stories(tar.extractfile(task_path.format('train')))
    test = get_stories(tar.extractfile(task_path.format('test')))
    return train, test

def get_stories(f, only_supporting=False, max_length=None):
    """Given a file name, read the file, retrieve the stories, and then convert the sentences into a single story.
    If max_length is supplied, any stories longer than max_length tokens will be discarded.
    """
    data = parse_stories(f.readlines(), only_supporting=only_supporting)
    data = [(story, q, answer) for story, q, answer in data if
            not max_length or len(story) < max_length]
    return data
    

def parse_stories(lines, only_supporting=False):
    """
    Parse the bAbI task format.
    If only_supporting is True, only the sentences that support the answer are kept.
    """
    data = []
    story = []
    for line in lines:
        line = line.decode('utf-8').strip()
        nid, line = line.split(' ', 1)
        nid = int(nid)
        if nid == 1:
            story = []
        if '\t' in line:
            q, a, supporting = line.split('\t')
            q = tokenize_word(q)
            if only_supporting:
                # Only select the related substory
                supporting = map(int, supporting.split())
                substory = [story[i - 1] for i in supporting]
            else:
                # Provide all the substories
                substory = [x for x in story if x]
            data.append((substory, q, a))
            story.append('')
        else:
            sent = tokenize_word(line)
            story.append(sent)
    return data


def tokenize_word(sent):
    """Return the tokens of a sentence excluding punctuation.
    >> tokenize('Bob dropped the apple. Where is the apple?')
    ['Bob', 'dropped', 'the', 'apple', 'Bob', 'went', 'to', 'the', 'kitchen']
    """
    return [x.strip() for x in re.split('(\W+)?', sent) if x.strip()]


def vectorize_stories(data, word_idx, sentence_maxlen, story_maxlen, query_maxlen):
    X = []
    Xq = []
    Y = []
    X_length = []

    for story, query, answer in data:
        sentences = []
        for s in story:
            sentence = [word_idx[w] for w in s]
            for _ in range(sentence_maxlen - len(sentence)):
                sentence.append(0)
            assert len(sentence) == sentence_maxlen
            sentences.append(sentence)
        X_length.append(len(sentences))

        ## story
        for _ in range(story_maxlen - len(sentences)):
            sentences.append([0 for _ in range(sentence_maxlen)])

        ## query
        xq = [word_idx[w] for w in query]
        for _ in range(query_maxlen - len(xq)):
            xq.append(0)
        ## answer
        y = np.zeros(len(word_idx) + 1)  # index 0 is reserved
        y[word_idx[answer]] = 1

        X.append(sentences)
        Xq.append(xq)
        Y.append(y)

    return X, Xq, np.array(Y), X_length

# %%
reset_graph()
tasks = [
    'qa1_single-supporting-fact', 'qa2_two-supporting-facts', 'qa3_three-supporting-facts',
    'qa4_two-arg-relations', 'qa5_three-arg-relations', 'qa6_yes-no-questions', 'qa7_counting',
    'qa8_lists-sets', 'qa9_simple-negation', 'qa10_indefinite-knowledge',
    'qa11_basic-coreference', 'qa12_conjunction', 'qa13_compound-coreference',
    'qa14_time-reasoning', 'qa15_basic-deduction', 'qa16_basic-induction', 'qa17_positional-reasoning',
    'qa18_size-reasoning', 'qa19_path-finding', 'qa20_agents-motivations'
]

verbose = True
path = 'babi/babi_tasks_data_1_20_v1.2.tar.gz'
tar = tarfile.open(path)
tasks_dir = 'tasks_1-20_v1-2/en/'


for task in tasks:
    print('\n**************************************\n')
    print(task)
    
    task_path = tasks_dir + task + '_{}.txt'
    train, test = get_data(task_path)
    
    flatten = lambda data: [i for i in chain(*data)]
    vocab = sorted(reduce(lambda x, y: x | y, (set(flatten(story) + q + [answer])
                                               for story, q, answer in train + test)))

    # 0 is reserved for masking via pad_sequences
    vocab_size = len(vocab) + 1
    word_idx = dict((c, i + 1) for i, c in enumerate(vocab))

    sentence_maxlen = max(flatten([[len(s) for s in x] for x, _, _ in train + test]))
    #sentence_maxlen = max([i for i in chain(*[[len(s) for s in x] for x, _, _ in train + test])])
    story_maxlen = max(map(len, (x for x, _, _ in train + test)))
    query_maxlen = max(map(len, (x for _, x, _ in train + test)))
    
    idx_word = {v: k for k, v in word_idx.iteritems()}
    idx_word[0] = "_PAD"
     
    X, Xq, Y, X_length = vectorize_stories(train, word_idx, sentence_maxlen, story_maxlen, query_maxlen)
    tX, tXq, tY, tX_length = vectorize_stories(test, word_idx, sentence_maxlen, story_maxlen, query_maxlen)
    
    if verbose:
        print('vocab = {}'.format(vocab))
        print('word_idx = {}'.format(word_idx))
        print('X.shape = {}'.format(np.array(X).shape))
        print('Xq.shape = {}'.format(np.array(Xq).shape))
        print('Y.shape = {}'.format(Y.shape))
        print('story_maxlen, sentence_maxlen, query_maxlen = {}, {}, {}'.format(story_maxlen, sentence_maxlen, query_maxlen))

    config = Config()
    config.vocab_size = vocab_size
    config.num_steps_sentence = sentence_maxlen
    config.num_steps_story = story_maxlen
    config.num_steps_question = query_maxlen
    print('max_epochs = {}'.format(config.max_epochs)) 
    with tf.Graph().as_default() as g:
        model = RNN_Model(config)
        init = tf.global_variables_initializer()

        with tf.Session() as session:
            session.run(init)

            for epoch in range(config.max_epochs):
                print('Epoch {}'.format(epoch))

                train_loss, train_acc, val_acc, Story, Question, Answer, Prediction = model.run_epoch(session, (
                    X, Xq, Y, X_length), train_op=model.train_step)

                if verbose:
                    print('Training loss: {}'.format(train_loss))
                    print('Training acc: {}'.format(train_acc))
                    print('Validation acc: {}'.format(val_acc))


                if epoch % 20 == 0:
                    test_acc = model.predict(session, (tX, tXq, tY, tX_length))
                    print('Testing acc: {}'.format(test_acc))
# Out:
# **************************************
#
# qa1_single-supporting-fact
# vocab = [u'.', u'?', u'Daniel', u'John', u'Mary', u'Sandra', u'Where', u'back', u'bathroom', u'bedroom', u'garden', u'hallway', u'is', u'journeyed', u'kitchen', u'moved', u'office', u'the', u'to', u'travelled', u'went']
# word_idx = {u'hallway': 12, u'bathroom': 9, u'garden': 11, u'journeyed': 14, u'office': 17, u'is': 13, u'bedroom': 10, u'moved': 16, u'back': 8, u'went': 21, u'.': 1, u'to': 19, u'travelled': 20, u'Daniel': 3, u'Sandra': 6, u'the': 18, u'John': 4, u'Where': 7, u'Mary': 5, u'?': 2, u'kitchen': 15}
# X.shape = (1000, 10, 7)
# Xq.shape = (1000, 4)
# Y.shape = (1000, 22)
# story_maxlen, sentence_maxlen, query_maxlen = 10, 7, 4
# max_epochs = 500
# Epoch 0
# Training loss: 21.600284576485
# Training acc: 0.142857142857
# Validation acc: 0.125
# Testing acc: 0.193548387097
# Epoch 1
# Training loss: 6.8392348289587
# Training acc: 0.15625
# Validation acc: 0.229166666667
# Epoch 2
# 20 / 28 : loss = 5.76768684387Training loss: 5.55673456192
# Training acc: 0.145089285714
# Validation acc: 0.177083333333
# Epoch 3
# Training loss: 4.1934061050418
# Training acc: 0.197544642857
# Validation acc: 0.21875
# Epoch 4
# Training loss: 4.1510415077274
# Training acc: 0.166294642857
# Validation acc: 0.166666666667
# Epoch 5
# Training loss: 4.0519576072729
# Training acc: 0.166294642857
# Validation acc: 0.125
# Epoch 6
# Training loss: 3.6324136257219
# Training acc: 0.186383928571
# Validation acc: 0.208333333333
# Epoch 7
# 20 / 28 : loss = 3.48065066338Training loss: 3.56810879707
# Training acc: 0.142857142857
# Validation acc: 0.15625
# Epoch 8
# Training loss: 3.4260022640237
# Training acc: 0.142857142857
# Validation acc: 0.1875
# Epoch 9
# Training loss: 3.3417522907372
# Training acc: 0.160714285714
# Validation acc: 0.208333333333
# Epoch 10
# Training loss: 3.1969330310867
# Training acc: 0.143973214286
# Validation acc: 0.135416666667
# Epoch 11
# 20 / 28 : loss = 3.03989863396Training loss: 3.03022456169
# Training acc: 0.150669642857
# Validation acc: 0.145833333333
# Epoch 12
# 20 / 28 : loss = 2.97115898132Training loss: 2.96236014366
# Training acc: 0.176339285714
# Validation acc: 0.09375
# Epoch 13
# Training loss: 2.7531032562331
# Training acc: 0.177455357143
# Validation acc: 0.177083333333
# Epoch 14
# 20 / 28 : loss = 2.91783952713Training loss: 2.88287043571
# Training acc: 0.159598214286
# Validation acc: 0.197916666667
# Epoch 15
# 20 / 28 : loss = 2.71773386002Training loss: 2.70561647415
# Training acc: 0.171875
# Validation acc: 0.197916666667
# Epoch 16
# 20 / 28 : loss = 2.53625106812Training loss: 2.57977294922
# Training acc: 0.203125
# Validation acc: 0.177083333333
# Epoch 17
# 20 / 28 : loss = 2.59431171417Training loss: 2.57954668999
# Training acc: 0.176339285714
# Validation acc: 0.15625
# Epoch 18
# 20 / 28 : loss = 2.63727641106Training loss: 2.60585856438
# Training acc: 0.172991071429
# Validation acc: 0.1875
# Epoch 19
# 20 / 28 : loss = 2.54490661621Training loss: 2.52765917778
# Training acc: 0.165178571429
# Validation acc: 0.135416666667
# Epoch 20
# 20 / 28 : loss = 2.49858570099Training loss: 2.52533698082
# Training acc: 0.158482142857
# Validation acc: 0.135416666667
# Testing acc: 0.154233870968
# Epoch 21
# Training loss: 2.4773271083877
# Training acc: 0.166294642857
# Validation acc: 0.197916666667
# Epoch 22
# Training loss: 2.4450910091445
# Training acc: 0.168526785714
# Validation acc: 0.177083333333
# Epoch 23
# Training loss: 2.3731570243857
# Training acc: 0.177455357143
# Validation acc: 0.260416666667
# Epoch 24
# 20 / 28 : loss = 2.43170619011Training loss: 2.43687415123
# Training acc: 0.1484375
# Validation acc: 0.145833333333
# Epoch 25
# Training loss: 2.3384916782482
# Training acc: 0.178571428571
# Validation acc: 0.135416666667
# Epoch 26
# 20 / 28 : loss = 2.28617072105Training loss: 2.29642558098
# Training acc: 0.185267857143
# Validation acc: 0.15625
# Epoch 27
# Training loss: 2.3387141227737
# Training acc: 0.157366071429
# Validation acc: 0.125
# Epoch 28
# Training loss: 2.2592437267383
# Training acc: 0.178571428571
# Validation acc: 0.229166666667
# Epoch 29
# Training loss: 2.2767739296632
# Training acc: 0.167410714286
# Validation acc: 0.145833333333
# Epoch 30
# 20 / 28 : loss = 2.27940487862Training loss: 2.31166982651
# Training acc: 0.159598214286
# Validation acc: 0.1875
# Epoch 31
# 20 / 28 : loss = 2.23499011993Training loss: 2.25652527809
# Training acc: 0.155133928571
# Validation acc: 0.3125
# Epoch 32
# 20 / 28 : loss = 2.23755097389Training loss: 2.23910117149
# Training acc: 0.1796875
# Validation acc: 0.239583333333
# Epoch 33
# 20 / 28 : loss = 2.17189812669Training loss: 2.21501970291
# Training acc: 0.1640625
# Validation acc: 0.104166666667
# Epoch 34
# 20 / 28 : loss = 2.24072122574Training loss: 2.24468159676
# Training acc: 0.143973214286
# Validation acc: 0.177083333333
# Epoch 35
# 20 / 28 : loss = 2.15582036972Training loss: 2.15597701073
# Training acc: 0.1875
# Validation acc: 0.197916666667
# Epoch 36
# 20 / 28 : loss = 2.14840435982Training loss: 2.17284679413
# Training acc: 0.181919642857
# Validation acc: 0.166666666667
# Epoch 37
# 20 / 28 : loss = 2.25673413277Training loss: 2.25738954544
# Training acc: 0.145089285714
# Validation acc: 0.125
# Epoch 38
# 20 / 28 : loss = 2.19931817055Training loss: 2.16106748581
# Training acc: 0.161830357143
# Validation acc: 0.135416666667
# Epoch 39
# 20 / 28 : loss = 2.19684267044Training loss: 2.17047667503
# Training acc: 0.178571428571
# Validation acc: 0.15625
# Epoch 40
# Training loss: 2.1117529869197
# Training acc: 0.197544642857
# Validation acc: 0.166666666667
# Testing acc: 0.182459677419
# Epoch 41
# Training loss: 2.1357119083494
# Training acc: 0.204241071429
# Validation acc: 0.145833333333
# Epoch 42
# Training loss: 2.1584148407751
# Training acc: 0.203125
# Validation acc: 0.166666666667
# Epoch 43
# Training loss: 2.1246211528884
# Training acc: 0.212053571429
# Validation acc: 0.177083333333
# Epoch 44
# 20 / 28 : loss = 2.06249284744Training loss: 2.09279179573
# Training acc: 0.237723214286
# Validation acc: 0.260416666667
# Epoch 45
# 20 / 28 : loss = 2.02808117867Training loss: 2.02229070663
# Training acc: 0.258928571429
# Validation acc: 0.21875
# Epoch 46
# Training loss: 2.0230374336246
# Training acc: 0.256696428571
# Validation acc: 0.197916666667
# Epoch 47
# 20 / 28 : loss = 1.96023142338Training loss: 1.9977606535
# Training acc: 0.258928571429
# Validation acc: 0.322916666667
# Epoch 48
# 20 / 28 : loss = 1.98369562626Training loss: 1.97728812695
# Training acc: 0.274553571429
# Validation acc: 0.260416666667
# Epoch 49
# 20 / 28 : loss = 2.00502729416Training loss: 1.99746322632
# Training acc: 0.308035714286
# Validation acc: 0.375
# Epoch 50
# 20 / 28 : loss = 2.00355362892Training loss: 1.98265874386
# Training acc: 0.323660714286
# Validation acc: 0.3125
# Epoch 51
# 20 / 28 : loss = 1.87048089504Training loss: 1.91097044945
# Training acc: 0.372767857143
# Validation acc: 0.395833333333
# Epoch 52
# Training loss: 1.8708578348234
# Training acc: 0.391741071429
# Validation acc: 0.40625
# Epoch 53
# 20 / 28 : loss = 1.88762378693Training loss: 1.84108197689
# Training acc: 0.430803571429
# Validation acc: 0.541666666667
# Epoch 54
# 20 / 28 : loss = 1.76352965832Training loss: 1.75547027588
# Training acc: 0.458705357143
# Validation acc: 0.46875
# Epoch 55
# Training loss: 1.6894935369515
# Training acc: 0.457589285714
# Validation acc: 0.510416666667
# Epoch 56
# Training loss: 1.6485745906816
# Training acc: 0.498883928571
# Validation acc: 0.510416666667
# Epoch 57
# 20 / 28 : loss = 1.54667520523Training loss: 1.5720859766
# Training acc: 0.501116071429
# Validation acc: 0.489583333333
# Epoch 58
# 20 / 28 : loss = 1.59672129154Training loss: 1.57721793652
# Training acc: 0.5078125
# Validation acc: 0.520833333333
# Epoch 59
# 20 / 28 : loss = 1.48650610447Training loss: 1.46418344975
# Training acc: 0.540178571429
# Validation acc: 0.53125
# Epoch 60
# 20 / 28 : loss = 1.47642445564Training loss: 1.47215235233
# Training acc: 0.545758928571
# Validation acc: 0.520833333333
# Testing acc: 0.498991935484
# Epoch 61
# Training loss: 1.3811770677628
# Training acc: 0.543526785714
# Validation acc: 0.520833333333
# Epoch 62
# Training loss: 1.4358463287414
# Training acc: 0.5390625
# Validation acc: 0.510416666667
# Epoch 63
# 20 / 28 : loss = 1.34154260159Training loss: 1.38572585583
# Training acc: 0.549107142857
# Validation acc: 0.552083333333
# Epoch 64
# 20 / 28 : loss = 1.30192208297Training loss: 1.37405371666
# Training acc: 0.540178571429
# Validation acc: 0.489583333333
# Epoch 65
# 20 / 28 : loss = 1.38958740234Training loss: 1.38727927208
# Training acc: 0.558035714286
# Validation acc: 0.572916666667
# Epoch 66
# 20 / 28 : loss = 1.32687509066Training loss: 1.31049454212
# Training acc: 0.572544642857
# Validation acc: 0.510416666667
# Epoch 67
# 20 / 28 : loss = 1.32011353974Training loss: 1.31522381306
# Training acc: 0.561383928571
# Validation acc: 0.510416666667
# Epoch 68
# 20 / 28 : loss = 1.38734745979Training loss: 1.35305476189
# Training acc: 0.547991071429
# Validation acc: 0.520833333333
# Epoch 69
# 20 / 28 : loss = 1.29114627838Training loss: 1.29696929455
# Training acc: 0.550223214286
# Validation acc: 0.489583333333
# Epoch 70
# 20 / 28 : loss = 1.31514930725Training loss: 1.29468512535
# Training acc: 0.573660714286
# Validation acc: 0.552083333333
# Epoch 71
# 20 / 28 : loss = 1.29642927647Training loss: 1.31097793579
# Training acc: 0.573660714286
# Validation acc: 0.583333333333
# Epoch 72
# 20 / 28 : loss = 1.22922372818Training loss: 1.27054655552
# Training acc: 0.580357142857
# Validation acc: 0.604166666667
# Epoch 73
# 20 / 28 : loss = 1.26430022717Training loss: 1.28624093533
# Training acc: 0.579241071429
# Validation acc: 0.510416666667
# Epoch 74
# 20 / 28 : loss = 1.24093520641Training loss: 1.26317667961
# Training acc: 0.5703125
# Validation acc: 0.645833333333
# Epoch 75
# 20 / 28 : loss = 1.26393532753Training loss: 1.26087749004
# Training acc: 0.5625
# Validation acc: 0.520833333333
# Epoch 76
# 20 / 28 : loss = 1.24528372288Training loss: 1.25385677814
# Training acc: 0.582589285714
# Validation acc: 0.541666666667
# Epoch 77
# Training loss: 1.2513552904196
# Training acc: 0.587053571429
# Validation acc: 0.572916666667
# Epoch 78
# 20 / 28 : loss = 1.19037091732Training loss: 1.21754968166
# Training acc: 0.583705357143
# Validation acc: 0.614583333333
# Epoch 79
# 20 / 28 : loss = 1.19250965118Training loss: 1.22269284725
# Training acc: 0.595982142857
# Validation acc: 0.635416666667
# Epoch 80
# 20 / 28 : loss = 1.20094990734Training loss: 1.21758675575
# Training acc: 0.590401785714
# Validation acc: 0.614583333333
# Testing acc: 0.516129032258
# Epoch 81
# Training loss: 1.1861031055533
# Training acc: 0.609375
# Validation acc: 0.520833333333
# Epoch 82
# Training loss: 1.1657896041922
# Training acc: 0.631696428571
# Validation acc: 0.59375
# Epoch 83
# 20 / 28 : loss = 1.24596893787Training loss: 1.22318303585
# Training acc: 0.581473214286
# Validation acc: 0.6875
# Epoch 84
# Training loss: 1.2052034139683
# Training acc: 0.6171875
# Validation acc: 0.645833333333
# Epoch 85
# 20 / 28 : loss = 1.15781199932Training loss: 1.17923152447
# Training acc: 0.608258928571
# Validation acc: 0.583333333333
# Epoch 86
# 20 / 28 : loss = 1.18807983398Training loss: 1.16662919521
# Training acc: 0.630580357143
# Validation acc: 0.520833333333
# Epoch 87
# 20 / 28 : loss = 1.16868042946Training loss: 1.16278743744
# Training acc: 0.6171875
# Validation acc: 0.614583333333
# Epoch 88
# 20 / 28 : loss = 1.16030669212Training loss: 1.14828121662
# Training acc: 0.638392857143
# Validation acc: 0.541666666667
# Epoch 89
# 20 / 28 : loss = 1.15978014469Training loss: 1.17318367958
# Training acc: 0.618303571429
# Validation acc: 0.708333333333
# Epoch 90
# 20 / 28 : loss = 1.11522591114Training loss: 1.09825956821
# Training acc: 0.649553571429
# Validation acc: 0.541666666667
# Epoch 91
# Training loss: 1.1202839613806
# Training acc: 0.626116071429
# Validation acc: 0.635416666667
# Epoch 92
# Training loss: 1.1289079189323
# Training acc: 0.640625
# Validation acc: 0.71875
# Epoch 93
# 20 / 28 : loss = 1.10134828091Training loss: 1.09000730515
# Training acc: 0.661830357143
# Validation acc: 0.614583333333
# Epoch 94
# 20 / 28 : loss = 1.09081900129Training loss: 1.08697009087
# Training acc: 0.650669642857
# Validation acc: 0.65625
# Epoch 95
# Training loss: 1.1272166967475
# Training acc: 0.641741071429
# Validation acc: 0.697916666667
# Epoch 96
# Training loss: 1.0542430877707
# Training acc: 0.6796875
# Validation acc: 0.65625
# Epoch 97
# 20 / 28 : loss = 1.08178842068Training loss: 1.09366428852
# Training acc: 0.645089285714
# Validation acc: 0.6875
# Epoch 98
# Training loss: 1.0515012741199
# Training acc: 0.665178571429
# Validation acc: 0.677083333333
# Epoch 99
# 20 / 28 : loss = 1.07903885841Training loss: 1.05897927284
# Training acc: 0.689732142857
# Validation acc: 0.635416666667
# Epoch 100
# Training loss: 1.0329686403382
# Training acc: 0.690848214286
# Validation acc: 0.635416666667
# Testing acc: 0.495967741935
# Epoch 101
# Training loss: 1.0348943471933
# Training acc: 0.704241071429
# Validation acc: 0.697916666667
# Epoch 102
# Training loss: 1.0419386625366
# Training acc: 0.699776785714
# Validation acc: 0.65625
# Epoch 103
# 20 / 28 : loss = 1.015476465239Training loss: 1.04238629341
# Training acc: 0.681919642857
# Validation acc: 0.59375
# Epoch 104
# Training loss: 1.00549721718885
# Training acc: 0.705357142857
# Validation acc: 0.645833333333
# Epoch 105
# 20 / 28 : loss = 1.011239409455Training loss: 1.04509556293
# Training acc: 0.676339285714
# Validation acc: 0.739583333333
# Epoch 106
# 20 / 28 : loss = 0.974842250347Training loss: 1.01322424412
# Training acc: 0.723214285714
# Validation acc: 0.708333333333
# Epoch 107
# 20 / 28 : loss = 1.03923285007Training loss: 1.02526724339
# Training acc: 0.715401785714
# Validation acc: 0.75
# Epoch 108
# 20 / 28 : loss = 1.015491724019Training loss: 1.00587356091
# Training acc: 0.715401785714
# Validation acc: 0.760416666667
# Epoch 109
# 20 / 28 : loss = 0.972155869007Training loss: 0.980734169483
# Training acc: 0.741071428571
# Validation acc: 0.739583333333
# Epoch 110
# 20 / 28 : loss = 0.900819778442Training loss: 0.937850475311
# Training acc: 0.758928571429
# Validation acc: 0.770833333333
# Epoch 111
# 20 / 28 : loss = 0.970808684826Training loss: 0.979670882225
# Training acc: 0.738839285714
# Validation acc: 0.802083333333
# Epoch 112
# 20 / 28 : loss = 0.923471271992Training loss: 0.984100162983
# Training acc: 0.764508928571
# Validation acc: 0.78125
# Epoch 113
# 20 / 28 : loss = 1.00447368622Training loss: 0.994886040688
# Training acc: 0.737723214286
# Validation acc: 0.78125
# Epoch 114
# Training loss: 1.00390768051394
# Training acc: 0.744419642857
# Validation acc: 0.833333333333
# Epoch 115
# Training loss: 0.94926995039366
# Training acc: 0.746651785714
# Validation acc: 0.802083333333
# Epoch 116
# 20 / 28 : loss = 0.942889630795Training loss: 0.949985921383
# Training acc: 0.754464285714
# Validation acc: 0.760416666667
# Epoch 117
# Training loss: 0.92044001817793
# Training acc: 0.785714285714
# Validation acc: 0.729166666667
# Epoch 118
# 20 / 28 : loss = 0.937143445015Training loss: 0.944421708584
# Training acc: 0.765625
# Validation acc: 0.791666666667
# Epoch 119
# 20 / 28 : loss = 0.900097250938Training loss: 0.914961278439
# Training acc: 0.787946428571
# Validation acc: 0.78125
# Epoch 120
# Training loss: 0.94279056787582
# Training acc: 0.770089285714
# Validation acc: 0.84375
# Testing acc: 0.495967741935
# Epoch 121
# Training loss: 0.91048663854616
# Training acc: 0.783482142857
# Validation acc: 0.802083333333
# Epoch 122
# Training loss: 0.8778281807956
# Training acc: 0.814732142857
# Validation acc: 0.864583333333
# Epoch 123
# Training loss: 0.92963731288922
# Training acc: 0.787946428571
# Validation acc: 0.822916666667
# Epoch 124
# 20 / 28 : loss = 0.952214658264Training loss: 0.916846454144
# Training acc: 0.796875
# Validation acc: 0.854166666667
# Epoch 125
# 20 / 28 : loss = 0.890395462513Training loss: 0.933344960213
# Training acc: 0.797991071429
# Validation acc: 0.854166666667
# Epoch 126
# Training loss: 0.87273132801122
# Training acc: 0.824776785714
# Validation acc: 0.916666666667
# Epoch 127
# 20 / 28 : loss = 0.871614277363Training loss: 0.874284625053
# Training acc: 0.827008928571
# Validation acc: 0.8125
# Epoch 128
# Training loss: 0.87897270917995
# Training acc: 0.833705357143
# Validation acc: 0.916666666667
# Epoch 129
# 20 / 28 : loss = 0.828765332699Training loss: 0.851428687572
# Training acc: 0.840401785714
# Validation acc: 0.84375
# Epoch 130
# 20 / 28 : loss = 0.820893764496Training loss: 0.873503744602
# Training acc: 0.830357142857
# Validation acc: 0.927083333333
# Epoch 131
# Training loss: 0.86668676137921
# Training acc: 0.850446428571
# Validation acc: 0.885416666667
# Epoch 132
# Training loss: 0.80919170379667
# Training acc: 0.862723214286
# Validation acc: 0.895833333333
# Epoch 133
# 20 / 28 : loss = 0.842033207417Training loss: 0.836847901344
# Training acc: 0.844866071429
# Validation acc: 0.927083333333
# Epoch 134
# 20 / 28 : loss = 0.762813031673Training loss: 0.784306585789
# Training acc: 0.888392857143
# Validation acc: 0.885416666667
# Epoch 135
# 20 / 28 : loss = 0.819425702095Training loss: 0.819759070873
# Training acc: 0.852678571429
# Validation acc: 0.885416666667
# Epoch 136
# Training loss: 0.82120186090503
# Training acc: 0.856026785714
# Validation acc: 0.927083333333
# Epoch 137
# 20 / 28 : loss = 0.756728410721Training loss: 0.785184979439
# Training acc: 0.887276785714
# Validation acc: 0.895833333333
# Epoch 138
# 20 / 28 : loss = 0.803984880447Training loss: 0.845272362232
# Training acc: 0.841517857143
# Validation acc: 0.854166666667
# Epoch 139
# Training loss: 0.79843091964718
# Training acc: 0.862723214286
# Validation acc: 0.947916666667
# Epoch 140
# 20 / 28 : loss = 0.856138706207Training loss: 0.848366558552
# Training acc: 0.858258928571
# Validation acc: 0.864583333333
# Testing acc: 0.460685483871
# Epoch 141
# Training loss: 0.82200908660902
# Training acc: 0.8671875
# Validation acc: 0.96875
# Epoch 142
# Training loss: 0.73485678434408
# Training acc: 0.896205357143
# Validation acc: 0.916666666667
# Epoch 143
# 20 / 28 : loss = 0.733393609524Training loss: 0.752783298492
# Training acc: 0.888392857143
# Validation acc: 0.895833333333
# Epoch 144
# 20 / 28 : loss = 0.797252357006Training loss: 0.832644104958
# Training acc: 0.858258928571
# Validation acc: 0.96875
# Epoch 145
# Training loss: 0.75160634517747
# Training acc: 0.893973214286
# Validation acc: 0.927083333333
# Epoch 146
# Training loss: 0.79208505153707
# Training acc: 0.885044642857
# Validation acc: 0.895833333333
# Epoch 147
# 20 / 28 : loss = 0.814554393291Training loss: 0.801267445087
# Training acc: 0.876116071429
# Validation acc: 0.927083333333
# Epoch 148
# 20 / 28 : loss = 0.792596340179Training loss: 0.800757110119
# Training acc: 0.866071428571
# Validation acc: 0.916666666667
# Epoch 149
# Training loss: 0.78759348392551
# Training acc: 0.890625
# Validation acc: 0.927083333333
# Epoch 150
# Training loss: 0.77864891290749
# Training acc: 0.891741071429
# Validation acc: 0.90625
# Epoch 151
# Training loss: 0.72845607996879
# Training acc: 0.912946428571
# Validation acc: 0.947916666667
# Epoch 152
# 20 / 28 : loss = 0.767798304558Training loss: 0.777148723602
# Training acc: 0.879464285714
# Validation acc: 0.9375
# Epoch 153
# 20 / 28 : loss = 0.742514908314Training loss: 0.747435927391
# Training acc: 0.897321428571
# Validation acc: 0.947916666667
# Epoch 154
# Training loss: 0.76815712451916
# Training acc: 0.891741071429
# Validation acc: 0.9375
# Epoch 155
# Training loss: 0.71138876676672
# Training acc: 0.926339285714
# Validation acc: 0.90625
# Epoch 156
# Training loss: 0.73693048954514
# Training acc: 0.901785714286
# Validation acc: 0.885416666667
# Epoch 157
# Training loss: 0.77254974842165
# Training acc: 0.886160714286
# Validation acc: 0.927083333333
# Epoch 158
# 20 / 28 : loss = 0.723805844784Training loss: 0.709708333015
# Training acc: 0.924107142857
# Validation acc: 0.979166666667
# Epoch 159
# 20 / 28 : loss = 0.693283557892Training loss: 0.702533841133
# Training acc: 0.918526785714
# Validation acc: 0.875
# Epoch 160
# 20 / 28 : loss = 0.734006404877Training loss: 0.741523742676
# Training acc: 0.899553571429
# Validation acc: 0.958333333333
# Testing acc: 0.447580645161
# Epoch 161
# Training loss: 0.76398193836249
# Training acc: 0.90625
# Validation acc: 0.927083333333
# Epoch 162
# Training loss: 0.76406699419919
# Training acc: 0.890625
# Validation acc: 0.947916666667
# Epoch 163
# Training loss: 0.70267575979253
# Training acc: 0.924107142857
# Validation acc: 0.895833333333
# Epoch 164
# 20 / 28 : loss = 0.659737110138Training loss: 0.729647576809
# Training acc: 0.912946428571
# Validation acc: 0.947916666667
# Epoch 165
# Training loss: 0.76067394018243
# Training acc: 0.900669642857
# Validation acc: 0.916666666667
# Epoch 166
# Training loss: 0.71266311407141
# Training acc: 0.912946428571
# Validation acc: 0.958333333333
# Epoch 167
# Training loss: 0.70773088932949
# Training acc: 0.916294642857
# Validation acc: 0.916666666667
# Epoch 168
# 20 / 28 : loss = 0.720309793949Training loss: 0.734231591225
# Training acc: 0.895089285714
# Validation acc: 0.927083333333
# Epoch 169
# 20 / 28 : loss = 0.666813969612Training loss: 0.674693048
# Training acc: 0.931919642857
# Validation acc: 0.947916666667
# Epoch 170
# Training loss: 0.71893227100431
# Training acc: 0.915178571429
# Validation acc: 0.958333333333
# Epoch 171
# Training loss: 0.71332675218649
# Training acc: 0.9140625
# Validation acc: 0.96875
# Epoch 172
# 20 / 28 : loss = 0.649847984314Training loss: 0.672523498535
# Training acc: 0.9296875
# Validation acc: 0.958333333333
# Epoch 173
# 20 / 28 : loss = 0.649680256844Training loss: 0.667214095592
# Training acc: 0.926339285714
# Validation acc: 0.947916666667
# Epoch 174
# Training loss: 0.67467409372395
# Training acc: 0.930803571429
# Validation acc: 0.9375
# Epoch 175
# 20 / 28 : loss = 0.667432069778Training loss: 0.664578974247
# Training acc: 0.935267857143
# Validation acc: 0.96875
# Epoch 176
# Training loss: 0.63910830020993
# Training acc: 0.938616071429
# Validation acc: 1.0
# Epoch 177
# 20 / 28 : loss = 0.675542175773Training loss: 0.674198567867
# Training acc: 0.924107142857
# Validation acc: 0.947916666667
# Epoch 178
# Training loss: 0.72416859865299
# Training acc: 0.905133928571
# Validation acc: 0.979166666667
# Epoch 179
# 20 / 28 : loss = 0.675879597664Training loss: 0.704857409
# Training acc: 0.912946428571
# Validation acc: 0.96875
# Epoch 180
# 20 / 28 : loss = 0.699187815189Training loss: 0.716245830059
# Training acc: 0.907366071429
# Validation acc: 0.947916666667
# Testing acc: 0.46875
# Epoch 181
# Training loss: 0.71372640132987
# Training acc: 0.90625
# Validation acc: 0.9375
# Epoch 182
# Training loss: 0.69797706604215
# Training acc: 0.921875
# Validation acc: 0.96875
# Epoch 183
# Training loss: 0.66518449783341
# Training acc: 0.934151785714
# Validation acc: 0.989583333333
# Epoch 184
# Training loss: 0.74210804700956
# Training acc: 0.905133928571
# Validation acc: 0.958333333333
# Epoch 185
# 20 / 28 : loss = 0.629029154778Training loss: 0.648027598858
# Training acc: 0.946428571429
# Validation acc: 1.0
# Epoch 186
# 20 / 28 : loss = 0.635719120502Training loss: 0.638462007046
# Training acc: 0.9453125
# Validation acc: 0.96875
# Epoch 187
# Training loss: 0.62487000227582
# Training acc: 0.9453125
# Validation acc: 0.958333333333
# Epoch 188
# 20 / 28 : loss = 0.730486512184Training loss: 0.743897974491
# Training acc: 0.901785714286
# Validation acc: 0.916666666667
# Epoch 189
# Training loss: 0.67123699188293
# Training acc: 0.9296875
# Validation acc: 0.947916666667
# Epoch 190
# Training loss: 0.63837003707902
# Training acc: 0.940848214286
# Validation acc: 0.979166666667
# Epoch 191
# Training loss: 0.63786250352933
# Training acc: 0.9453125
# Validation acc: 0.989583333333
# Epoch 192
# Training loss: 0.63008135557202
# Training acc: 0.949776785714
# Validation acc: 0.958333333333
# Epoch 193
# 20 / 28 : loss = 0.671319663525Training loss: 0.684414088726
# Training acc: 0.918526785714
# Validation acc: 0.895833333333
# Epoch 194
# 20 / 28 : loss = 0.630957245827Training loss: 0.657352149487
# Training acc: 0.925223214286
# Validation acc: 0.9375
# Epoch 195
# 20 / 28 : loss = 0.615516066551Training loss: 0.649192452431
# Training acc: 0.9375
# Validation acc: 0.979166666667
# Epoch 196
# 20 / 28 : loss = 0.654511153698Training loss: 0.641484558582
# Training acc: 0.9375
# Validation acc: 0.979166666667
# Epoch 197
# Training loss: 0.6333016157157
# Training acc: 0.939732142857
# Validation acc: 0.947916666667
# Epoch 198
# 20 / 28 : loss = 0.629344463348Training loss: 0.639385342598
# Training acc: 0.941964285714
# Validation acc: 0.979166666667
# Epoch 199
# Training loss: 0.64490902423905
# Training acc: 0.939732142857
# Validation acc: 0.96875
# Epoch 200
# 20 / 28 : loss = 0.68651664257Training loss: 0.686764538288
# Training acc: 0.917410714286
# Validation acc: 0.979166666667
# Testing acc: 0.471774193548
# Epoch 201
# Training loss: 0.64037925005793
# Training acc: 0.943080357143
# Validation acc: 0.947916666667
# Epoch 202
# Training loss: 0.66538625955648
# Training acc: 0.928571428571
# Validation acc: 0.989583333333
# Epoch 203
# 20 / 28 : loss = 0.641122519979Training loss: 0.654503166676
# Training acc: 0.9296875
# Validation acc: 1.0
# Epoch 204
# 20 / 28 : loss = 0.643160700798Training loss: 0.674551129341
# Training acc: 0.9140625
# Validation acc: 1.0
# Epoch 205
# 20 / 28 : loss = 0.68803948164Training loss: 0.669700443745
# Training acc: 0.927455357143
# Validation acc: 0.96875
# Epoch 206
# Training loss: 0.61767244339812
# Training acc: 0.948660714286
# Validation acc: 0.979166666667
# Epoch 207
# 20 / 28 : loss = 0.603071510792Training loss: 0.622559189796
# Training acc: 0.9375
# Validation acc: 0.9375
# Epoch 208
# 20 / 28 : loss = 0.601498186588Training loss: 0.609133303165
# Training acc: 0.954241071429
# Validation acc: 0.958333333333
# Epoch 209
# 20 / 28 : loss = 0.608287572861Training loss: 0.616388142109
# Training acc: 0.948660714286
# Validation acc: 0.958333333333
# Epoch 210
# Training loss: 0.62492525577582
# Training acc: 0.934151785714
# Validation acc: 0.947916666667
# Epoch 211
# 20 / 28 : loss = 0.612704217434Training loss: 0.61242377758
# Training acc: 0.948660714286
# Validation acc: 0.958333333333
# Epoch 212
# Training loss: 0.66331017017423
# Training acc: 0.933035714286
# Validation acc: 0.96875
# Epoch 213
# 20 / 28 : loss = 0.666004478931Training loss: 0.665286719799
# Training acc: 0.926339285714
# Validation acc: 0.96875
# Epoch 214
# Training loss: 0.63412034511683
# Training acc: 0.938616071429
# Validation acc: 0.979166666667
# Epoch 215
# Training loss: 0.64443403482447
# Training acc: 0.936383928571
# Validation acc: 0.958333333333
# Epoch 216
# Training loss: 0.64197742939452
# Training acc: 0.934151785714
# Validation acc: 0.979166666667
# Epoch 217
# 20 / 28 : loss = 0.590448498726Training loss: 0.620010018349
# Training acc: 0.944196428571
# Validation acc: 0.96875
# Epoch 218
# 20 / 28 : loss = 0.623755812645Training loss: 0.615974485874
# Training acc: 0.949776785714
# Validation acc: 0.958333333333
# Epoch 219
# 20 / 28 : loss = 0.627965986729Training loss: 0.640066802502
# Training acc: 0.938616071429
# Validation acc: 0.958333333333
# Epoch 220
# Training loss: 0.69673150777816
# Training acc: 0.917410714286
# Validation acc: 0.927083333333
# Testing acc: 0.483870967742
# Epoch 221
# Training loss: 0.69755405187654
# Training acc: 0.920758928571
# Validation acc: 0.979166666667
# Epoch 222
# Training loss: 0.64070844650365
# Training acc: 0.943080357143
# Validation acc: 0.96875
# Epoch 223
# 20 / 28 : loss = 0.653108119965Training loss: 0.656799733639
# Training acc: 0.925223214286
# Validation acc: 0.989583333333
# Epoch 224
# 20 / 28 : loss = 0.626351952553Training loss: 0.627102851868
# Training acc: 0.9453125
# Validation acc: 1.0
# Epoch 225
# Training loss: 0.66140514612282
# Training acc: 0.925223214286
# Validation acc: 0.96875
# Epoch 226
# 20 / 28 : loss = 0.608820438385Training loss: 0.62785333395
# Training acc: 0.946428571429
# Validation acc: 0.989583333333
# Epoch 227
# Training loss: 0.64032256603269
# Training acc: 0.9296875
# Validation acc: 0.927083333333
# Epoch 228
# 20 / 28 : loss = 0.618730068207Training loss: 0.619984924793
# Training acc: 0.9453125
# Validation acc: 0.989583333333
# Epoch 229
# Training loss: 0.63473349809644
# Training acc: 0.935267857143
# Validation acc: 0.96875
# Epoch 230
# Training loss: 0.61687296629294
# Training acc: 0.943080357143
# Validation acc: 0.979166666667
# Epoch 231
# 20 / 28 : loss = 0.565869450569Training loss: 0.564219295979
# Training acc: 0.967633928571
# Validation acc: 0.989583333333
# Epoch 232
# 20 / 28 : loss = 0.545011460781Training loss: 0.574361920357
# Training acc: 0.955357142857
# Validation acc: 0.9375
# Epoch 233
# 20 / 28 : loss = 0.614556968212Training loss: 0.625551521778
# Training acc: 0.930803571429
# Validation acc: 0.979166666667
# Epoch 234
# 20 / 28 : loss = 0.602590680122Training loss: 0.600015163422
# Training acc: 0.949776785714
# Validation acc: 0.958333333333
# Epoch 235
# Training loss: 0.59176313877126
# Training acc: 0.948660714286
# Validation acc: 0.989583333333
# Epoch 236
# 20 / 28 : loss = 0.574431180954Training loss: 0.577381491661
# Training acc: 0.959821428571
# Validation acc: 0.979166666667
# Epoch 237
# Training loss: 0.59534323215571
# Training acc: 0.949776785714
# Validation acc: 0.989583333333
# Epoch 238
# Training loss: 0.61623769998651
# Training acc: 0.935267857143
# Validation acc: 0.947916666667
# Epoch 239
# 20 / 28 : loss = 0.606300473213Training loss: 0.626675307751
# Training acc: 0.936383928571
# Validation acc: 0.96875
# Epoch 240
# 20 / 28 : loss = 0.609014987946Training loss: 0.618138611317
# Training acc: 0.939732142857
# Validation acc: 0.916666666667
# Testing acc: 0.473790322581
# Epoch 241
# Training loss: 0.60489368438781
# Training acc: 0.949776785714
# Validation acc: 0.979166666667
# Epoch 242
# Training loss: 0.63993614912889
# Training acc: 0.939732142857
# Validation acc: 0.96875
# Epoch 243
# 20 / 28 : loss = 0.57542270422Training loss: 0.592394053936
# Training acc: 0.955357142857
# Validation acc: 0.96875
# Epoch 244
# Training loss: 0.63582319021282
# Training acc: 0.935267857143
# Validation acc: 0.96875
# Epoch 245
# Training loss: 0.60075026750674
# Training acc: 0.952008928571
# Validation acc: 0.989583333333
# Epoch 246
# 20 / 28 : loss = 0.581127643585Training loss: 0.597346782684
# Training acc: 0.948660714286
# Validation acc: 0.947916666667
# Epoch 247
# 20 / 28 : loss = 0.588456273079Training loss: 0.587449431419
# Training acc: 0.957589285714
# Validation acc: 0.979166666667
# Epoch 248
# 20 / 28 : loss = 0.634923636913Training loss: 0.624142289162
# Training acc: 0.935267857143
# Validation acc: 0.989583333333
# Epoch 249
# 20 / 28 : loss = 0.589036464691Training loss: 0.596610963345
# Training acc: 0.947544642857
# Validation acc: 0.989583333333
# Epoch 250
# Training loss: 0.58970034122537
# Training acc: 0.950892857143
# Validation acc: 0.96875
# Epoch 251
# Training loss: 0.56192529201541
# Training acc: 0.966517857143
# Validation acc: 0.989583333333
# Epoch 252
# 20 / 28 : loss = 0.552008092403Training loss: 0.558950722218
# Training acc: 0.964285714286
# Validation acc: 0.989583333333
# Epoch 253
# Training loss: 0.56365293264458
# Training acc: 0.948660714286
# Validation acc: 0.96875
# Epoch 254
# 20 / 28 : loss = 0.586044311523Training loss: 0.576860129833
# Training acc: 0.950892857143
# Validation acc: 1.0
# Epoch 255
# Training loss: 0.56436830759829
# Training acc: 0.963169642857
# Validation acc: 0.96875
# Epoch 256
# Training loss: 0.59225898981125
# Training acc: 0.943080357143
# Validation acc: 0.979166666667
# Epoch 257
# Training loss: 0.65060329437363
# Training acc: 0.930803571429
# Validation acc: 0.979166666667
# Epoch 258
# Training loss: 0.60470968484967
# Training acc: 0.943080357143
# Validation acc: 1.0
# Epoch 259
# 20 / 28 : loss = 0.595279991627Training loss: 0.610702455044
# Training acc: 0.947544642857
# Validation acc: 0.979166666667
# Epoch 260
# Training loss: 0.57432997226714
# Training acc: 0.9609375
# Validation acc: 0.989583333333
# Testing acc: 0.45564516129
# Epoch 261
# Training loss: 0.58039063215321
# Training acc: 0.946428571429
# Validation acc: 1.0
# Epoch 262
# Training loss: 0.54949772357942
# Training acc: 0.963169642857
# Validation acc: 0.979166666667
# Epoch 263
# 20 / 28 : loss = 0.577227056026Training loss: 0.585102975368
# Training acc: 0.944196428571
# Validation acc: 0.989583333333
# Epoch 264
# Training loss: 0.58482736349161
# Training acc: 0.9453125
# Validation acc: 0.96875
# Epoch 265
# 20 / 28 : loss = 0.583840012559Training loss: 0.594110369682
# Training acc: 0.946428571429
# Validation acc: 0.96875
# Epoch 266
# Training loss: 0.60154467821149
# Training acc: 0.943080357143
# Validation acc: 0.979166666667
# Epoch 267
# 20 / 28 : loss = 0.567110776901Training loss: 0.59859085083
# Training acc: 0.935267857143
# Validation acc: 0.916666666667
# Epoch 268
# Training loss: 0.56803572177923
# Training acc: 0.956473214286
# Validation acc: 1.0
# Epoch 269
# 20 / 28 : loss = 0.534487247467Training loss: 0.535071849823
# Training acc: 0.973214285714
# Validation acc: 1.0
# Epoch 270
# 20 / 28 : loss = 0.525823116302Training loss: 0.532406449318
# Training acc: 0.970982142857
# Validation acc: 0.979166666667
# Epoch 271
# 20 / 28 : loss = 0.512412905693Training loss: 0.526690423489
# Training acc: 0.963169642857
# Validation acc: 0.958333333333
# Epoch 272
# 20 / 28 : loss = 0.557487607002Training loss: 0.555054366589
# Training acc: 0.957589285714
# Validation acc: 1.0
# Epoch 273
# 20 / 28 : loss = 0.531226992607Training loss: 0.543025434017
# Training acc: 0.958705357143
# Validation acc: 0.979166666667
# Epoch 274
# 20 / 28 : loss = 0.561322510242Training loss: 0.582773506641
# Training acc: 0.947544642857
# Validation acc: 0.958333333333
# Epoch 275
# 20 / 28 : loss = 0.605216860771Training loss: 0.621206581593
# Training acc: 0.939732142857
# Validation acc: 0.947916666667
# Epoch 276
# 20 / 28 : loss = 0.611410021782Training loss: 0.601881086826
# Training acc: 0.948660714286
# Validation acc: 0.979166666667
# Epoch 277
# Training loss: 0.58853280544362
# Training acc: 0.943080357143
# Validation acc: 0.979166666667
# Epoch 278
# Training loss: 0.61251771451459
# Training acc: 0.930803571429
# Validation acc: 0.9375
# Epoch 279
# 20 / 28 : loss = 0.548470079899Training loss: 0.554292500019
# Training acc: 0.9609375
# Validation acc: 1.0
# Epoch 280
# 20 / 28 : loss = 0.538984596729Training loss: 0.542114257812
# Training acc: 0.967633928571
# Validation acc: 1.0
# Testing acc: 0.472782258065
# Epoch 281
# Training loss: 0.52103179693288
# Training acc: 0.967633928571
# Validation acc: 0.989583333333
# Epoch 282
# Training loss: 0.55595636367848
# Training acc: 0.950892857143
# Validation acc: 1.0
# Epoch 283
# 20 / 28 : loss = 0.524846613407Training loss: 0.526443064213
# Training acc: 0.966517857143
# Validation acc: 1.0
# Epoch 284
# 20 / 28 : loss = 0.564181983471Training loss: 0.555768251419
# Training acc: 0.948660714286
# Validation acc: 1.0
# Epoch 285
# Training loss: 0.54294860363802
# Training acc: 0.949776785714
# Validation acc: 1.0
# Epoch 286
# 20 / 28 : loss = 0.560906589031Training loss: 0.5603043437
# Training acc: 0.956473214286
# Validation acc: 0.979166666667
# Epoch 287
# Training loss: 0.54618823528333
# Training acc: 0.958705357143
# Validation acc: 0.96875
# Epoch 288
# Training loss: 0.56103998422682
# Training acc: 0.941964285714
# Validation acc: 0.979166666667
# Epoch 289
# 20 / 28 : loss = 0.562126219273Training loss: 0.575207710266
# Training acc: 0.946428571429
# Validation acc: 0.989583333333
# Epoch 290
# Training loss: 0.53645098209461
# Training acc: 0.963169642857
# Validation acc: 0.979166666667
# Epoch 291
# Training loss: 0.53780990839995
# Training acc: 0.963169642857
# Validation acc: 0.979166666667
# Epoch 292
# 20 / 28 : loss = 0.537977516651Training loss: 0.534238278866
# Training acc: 0.954241071429
# Validation acc: 0.989583333333
# Epoch 293
# 20 / 28 : loss = 0.500395059586Training loss: 0.523493170738
# Training acc: 0.965401785714
# Validation acc: 0.989583333333
# Epoch 294
# 20 / 28 : loss = 0.552581667994Training loss: 0.557201683521
# Training acc: 0.952008928571
# Validation acc: 0.989583333333
# Epoch 295
# Training loss: 0.55299156904259
# Training acc: 0.955357142857
# Validation acc: 0.96875
# Epoch 296
# 20 / 28 : loss = 0.578498721123Training loss: 0.574391901493
# Training acc: 0.941964285714
# Validation acc: 0.96875
# Epoch 297
# 20 / 28 : loss = 0.593929946423Training loss: 0.583629131317
# Training acc: 0.9453125
# Validation acc: 0.979166666667
# Epoch 298
# 20 / 28 : loss = 0.558305442333Training loss: 0.555441081524
# Training acc: 0.952008928571
# Validation acc: 0.979166666667
# Epoch 299
# 20 / 28 : loss = 0.549487411976Training loss: 0.550109565258
# Training acc: 0.950892857143
# Validation acc: 0.979166666667
# Epoch 300
# 20 / 28 : loss = 0.519260704517Training loss: 0.530870258808
# Training acc: 0.977678571429
# Validation acc: 0.989583333333
# Testing acc: 0.45060483871
# Epoch 301
# Training loss: 0.53592151403492
# Training acc: 0.9609375
# Validation acc: 0.979166666667
# Epoch 302
# Training loss: 0.52860814333119
# Training acc: 0.966517857143
# Validation acc: 0.979166666667
# Epoch 303
# 20 / 28 : loss = 0.510241091251Training loss: 0.518243789673
# Training acc: 0.964285714286
# Validation acc: 1.0
# Epoch 304
# 20 / 28 : loss = 0.519088387489Training loss: 0.520180761814
# Training acc: 0.969866071429
# Validation acc: 0.979166666667
# Epoch 305
# 20 / 28 : loss = 0.560044944286Training loss: 0.561307609081
# Training acc: 0.947544642857
# Validation acc: 0.979166666667
# Epoch 306
# Training loss: 0.52916938066583
# Training acc: 0.9609375
# Validation acc: 0.979166666667
# Epoch 307
# 20 / 28 : loss = 0.524477660656Training loss: 0.543414235115
# Training acc: 0.954241071429
# Validation acc: 0.989583333333
# Epoch 308
# Training loss: 0.53269177675282
# Training acc: 0.963169642857
# Validation acc: 0.989583333333
# Epoch 309
# 20 / 28 : loss = 0.545664250851Training loss: 0.548220336437
# Training acc: 0.950892857143
# Validation acc: 1.0
# Epoch 310
# 20 / 28 : loss = 0.546787023544Training loss: 0.560792684555
# Training acc: 0.948660714286
# Validation acc: 1.0
# Epoch 311
# 20 / 28 : loss = 0.587204873562Training loss: 0.581270694733
# Training acc: 0.939732142857
# Validation acc: 0.96875
# Epoch 312
# 20 / 28 : loss = 0.525293529034Training loss: 0.535544872284
# Training acc: 0.964285714286
# Validation acc: 0.979166666667
# Epoch 313
# 20 / 28 : loss = 0.543353021145Training loss: 0.553818464279
# Training acc: 0.952008928571
# Validation acc: 0.979166666667
# Epoch 314
# 20 / 28 : loss = 0.552347719669Training loss: 0.558060288429
# Training acc: 0.958705357143
# Validation acc: 0.989583333333
# Epoch 315
# Training loss: 0.54967272281661
# Training acc: 0.959821428571
# Validation acc: 1.0
# Epoch 316
# Training loss: 0.56153452396437
# Training acc: 0.953125
# Validation acc: 0.989583333333
# Epoch 317
# Training loss: 0.53642690181719
# Training acc: 0.963169642857
# Validation acc: 0.989583333333
# Epoch 318
# Training loss: 0.51359760761319
# Training acc: 0.969866071429
# Validation acc: 0.989583333333
# Epoch 319
# Training loss: 0.49284395575594
# Training acc: 0.9765625
# Validation acc: 0.989583333333
# Epoch 320
# Training loss: 0.47894665598979
# Training acc: 0.983258928571
# Validation acc: 0.979166666667
# Testing acc: 0.472782258065
# Epoch 321
# Training loss: 0.49218606948946
# Training acc: 0.975446428571
# Validation acc: 1.0
# Epoch 322
# 20 / 28 : loss = 0.491891443729Training loss: 0.496564805508
# Training acc: 0.974330357143
# Validation acc: 1.0
# Epoch 323
# 20 / 28 : loss = 0.494138658047Training loss: 0.495614081621
# Training acc: 0.970982142857
# Validation acc: 0.979166666667
# Epoch 324
# 20 / 28 : loss = 0.483875870705Training loss: 0.484041124582
# Training acc: 0.974330357143
# Validation acc: 0.989583333333
# Epoch 325
# Training loss: 0.51492822170305
# Training acc: 0.9609375
# Validation acc: 0.96875
# Epoch 326
# Training loss: 0.53692179918344
# Training acc: 0.948660714286
# Validation acc: 0.979166666667
# Epoch 327
# Training loss: 0.56841886043573
# Training acc: 0.936383928571
# Validation acc: 0.979166666667
# Epoch 328
# Training loss: 0.54242515564584
# Training acc: 0.954241071429
# Validation acc: 1.0
# Epoch 329
# 20 / 28 : loss = 0.522602736956Training loss: 0.555803775787
# Training acc: 0.950892857143
# Validation acc: 1.0
# Epoch 330
# 20 / 28 : loss = 0.57068580389Training loss: 0.57233273983
# Training acc: 0.946428571429
# Validation acc: 0.989583333333
# Epoch 331
# 20 / 28 : loss = 0.625930309296Training loss: 0.621887862682
# Training acc: 0.920758928571
# Validation acc: 0.947916666667
# Epoch 332
# 20 / 28 : loss = 0.573883354664Training loss: 0.576543450356
# Training acc: 0.959821428571
# Validation acc: 0.989583333333
# Epoch 333
# 20 / 28 : loss = 0.526847779751Training loss: 0.539049744606
# Training acc: 0.964285714286
# Validation acc: 0.979166666667
# Epoch 334
# 20 / 28 : loss = 0.507105350494Training loss: 0.514172494411
# Training acc: 0.973214285714
# Validation acc: 1.0
# Epoch 335
# 20 / 28 : loss = 0.513602375984Training loss: 0.511198937893
# Training acc: 0.967633928571
# Validation acc: 1.0
# Epoch 336
# Training loss: 0.47986128926384
# Training acc: 0.984375
# Validation acc: 0.989583333333
# Epoch 337
# 20 / 28 : loss = 0.471721649173Training loss: 0.471976310015
# Training acc: 0.977678571429
# Validation acc: 0.979166666667
# Epoch 338
# 20 / 28 : loss = 0.495025008917Training loss: 0.494066208601
# Training acc: 0.966517857143
# Validation acc: 1.0
# Epoch 339
# 20 / 28 : loss = 0.489308297634Training loss: 0.487580746412
# Training acc: 0.975446428571
# Validation acc: 1.0
# Epoch 340
# 20 / 28 : loss = 0.494741499424Training loss: 0.494252532721
# Training acc: 0.96875
# Validation acc: 0.989583333333
# Testing acc: 0.473790322581
# Epoch 341
# Training loss: 0.48672375083791
# Training acc: 0.972098214286
# Validation acc: 0.989583333333
# Epoch 342
# Training loss: 0.52044171094993
# Training acc: 0.964285714286
# Validation acc: 0.958333333333
# Epoch 343
# 20 / 28 : loss = 0.611192047596Training loss: 0.602629542351
# Training acc: 0.920758928571
# Validation acc: 0.979166666667
# Epoch 344
# 20 / 28 : loss = 0.521661877632Training loss: 0.546555936337
# Training acc: 0.950892857143
# Validation acc: 0.958333333333
# Epoch 345
# 20 / 28 : loss = 0.550417006016Training loss: 0.549945056438
# Training acc: 0.957589285714
# Validation acc: 0.96875
# Epoch 346
# 20 / 28 : loss = 0.545342743397Training loss: 0.544141411781
# Training acc: 0.957589285714
# Validation acc: 0.96875
# Epoch 347
# 20 / 28 : loss = 0.514137148857Training loss: 0.516517281532
# Training acc: 0.972098214286
# Validation acc: 0.989583333333
# Epoch 348
# Training loss: 0.51438593864403
# Training acc: 0.965401785714
# Validation acc: 0.96875
# Epoch 349
# Training loss: 0.49109330773429
# Training acc: 0.977678571429
# Validation acc: 0.989583333333
# Epoch 350
# 20 / 28 : loss = 0.519900083542Training loss: 0.51586574316
# Training acc: 0.959821428571
# Validation acc: 0.96875
# Epoch 351
# Training loss: 0.51916825771313
# Training acc: 0.963169642857
# Validation acc: 0.979166666667
# Epoch 352
# Training loss: 0.54573148489422
# Training acc: 0.949776785714
# Validation acc: 1.0
# Epoch 353
# Training loss: 0.52364176511841
# Training acc: 0.962053571429
# Validation acc: 0.989583333333
# Epoch 354
# 20 / 28 : loss = 0.517887413502Training loss: 0.522734999657
# Training acc: 0.963169642857
# Validation acc: 0.96875
# Epoch 355
# 20 / 28 : loss = 0.481997638941Training loss: 0.483160436153
# Training acc: 0.979910714286
# Validation acc: 1.0
# Epoch 356
# 20 / 28 : loss = 0.488787800074Training loss: 0.486885130405
# Training acc: 0.973214285714
# Validation acc: 1.0
# Epoch 357
# 20 / 28 : loss = 0.494752973318Training loss: 0.508616566658
# Training acc: 0.965401785714
# Validation acc: 0.979166666667
# Epoch 358
# Training loss: 0.53020650148481
# Training acc: 0.954241071429
# Validation acc: 1.0
# Epoch 359
# Training loss: 0.49899202585266
# Training acc: 0.967633928571
# Validation acc: 0.989583333333
# Epoch 360
# Training loss: 0.49156975746243
# Training acc: 0.975446428571
# Validation acc: 0.989583333333
# Testing acc: 0.479838709677
# Epoch 361
# Training loss: 0.51809108257312
# Training acc: 0.956473214286
# Validation acc: 1.0
# Epoch 362
# Training loss: 0.54789620637969
# Training acc: 0.944196428571
# Validation acc: 0.96875
# Epoch 363
# 20 / 28 : loss = 0.573192238808Training loss: 0.570484578609
# Training acc: 0.944196428571
# Validation acc: 0.979166666667
# Epoch 364
# Training loss: 0.53439575433756
# Training acc: 0.962053571429
# Validation acc: 0.989583333333
# Epoch 365
# 20 / 28 : loss = 0.491165518761Training loss: 0.496046721935
# Training acc: 0.972098214286
# Validation acc: 1.0
# Epoch 366
# 20 / 28 : loss = 0.479542553425Training loss: 0.480780035257
# Training acc: 0.979910714286
# Validation acc: 0.989583333333
# Epoch 367
# 20 / 28 : loss = 0.492506265647Training loss: 0.497014582157
# Training acc: 0.969866071429
# Validation acc: 0.979166666667
# Epoch 368
# 20 / 28 : loss = 0.485939711332Training loss: 0.487675249577
# Training acc: 0.969866071429
# Validation acc: 1.0
# Epoch 369
# 20 / 28 : loss = 0.465222507715Training loss: 0.470005095005
# Training acc: 0.984375
# Validation acc: 0.979166666667
# Epoch 370
# Training loss: 0.51169055700393
# Training acc: 0.956473214286
# Validation acc: 0.979166666667
# Epoch 371
# 20 / 28 : loss = 0.516012728214Training loss: 0.520716249943
# Training acc: 0.954241071429
# Validation acc: 0.927083333333
# Epoch 372
# 20 / 28 : loss = 0.527801930904Training loss: 0.52674549818
# Training acc: 0.957589285714
# Validation acc: 0.979166666667
# Epoch 373
# 20 / 28 : loss = 0.507346153259Training loss: 0.505443453789
# Training acc: 0.959821428571
# Validation acc: 0.979166666667
# Epoch 374
# 20 / 28 : loss = 0.478385984898Training loss: 0.485086768866
# Training acc: 0.96875
# Validation acc: 0.989583333333
# Epoch 375
# 20 / 28 : loss = 0.465915173292Training loss: 0.474019527435
# Training acc: 0.977678571429
# Validation acc: 0.989583333333
# Epoch 376
# 20 / 28 : loss = 0.462889134884Training loss: 0.461227327585
# Training acc: 0.96875
# Validation acc: 0.989583333333
# Epoch 377
# 20 / 28 : loss = 0.474845021963Training loss: 0.474899441004
# Training acc: 0.973214285714
# Validation acc: 1.0
# Epoch 378
# 20 / 28 : loss = 0.460042357445Training loss: 0.464619338512
# Training acc: 0.975446428571
# Validation acc: 1.0
# Epoch 379
# 20 / 28 : loss = 0.485413312912Training loss: 0.488762587309
# Training acc: 0.966517857143
# Validation acc: 1.0
# Epoch 380
# Training loss: 0.49261954426826
# Training acc: 0.970982142857
# Validation acc: 0.989583333333
# Testing acc: 0.459677419355
# Epoch 381
# Training loss: 0.47560030221968
# Training acc: 0.972098214286
# Validation acc: 1.0
# Epoch 382
# Training loss: 0.48915928602294
# Training acc: 0.96875
# Validation acc: 0.979166666667
# Epoch 383
# Training loss: 0.45913550257796
# Training acc: 0.984375
# Validation acc: 1.0
# Epoch 384
# 20 / 28 : loss = 0.505749821663Training loss: 0.520517408848
# Training acc: 0.958705357143
# Validation acc: 0.958333333333
# Epoch 385
# 20 / 28 : loss = 0.471545934677Training loss: 0.479077100754
# Training acc: 0.9765625
# Validation acc: 0.979166666667
# Epoch 386
# Training loss: 0.49071052670532
# Training acc: 0.964285714286
# Validation acc: 1.0
# Epoch 387
# Training loss: 0.50091171264655
# Training acc: 0.965401785714
# Validation acc: 1.0
# Epoch 388
# 20 / 28 : loss = 0.478916227818Training loss: 0.479406386614
# Training acc: 0.974330357143
# Validation acc: 1.0
# Epoch 389
# 20 / 28 : loss = 0.460648179054Training loss: 0.46070292592
# Training acc: 0.982142857143
# Validation acc: 0.989583333333
# Epoch 390
# 20 / 28 : loss = 0.480435192585Training loss: 0.495816498995
# Training acc: 0.959821428571
# Validation acc: 1.0
# Epoch 391
# 20 / 28 : loss = 0.473901033401Training loss: 0.477936416864
# Training acc: 0.974330357143
# Validation acc: 0.96875
# Epoch 392
# Training loss: 0.45799127221114
# Training acc: 0.977678571429
# Validation acc: 0.979166666667
# Epoch 393
# 20 / 28 : loss = 0.454225093126Training loss: 0.47661408782
# Training acc: 0.970982142857
# Validation acc: 0.96875
# Epoch 394
# Training loss: 0.52174323797245
# Training acc: 0.950892857143
# Validation acc: 0.989583333333
# Epoch 395
# Training loss: 0.50007849931764
# Training acc: 0.969866071429
# Validation acc: 0.989583333333
# Epoch 396
# Training loss: 0.48613128066111
# Training acc: 0.965401785714
# Validation acc: 1.0
# Epoch 397
# Training loss: 0.46473470330277
# Training acc: 0.979910714286
# Validation acc: 1.0
# Epoch 398
# Training loss: 0.46032109856624
# Training acc: 0.975446428571
# Validation acc: 0.979166666667
# Epoch 399
# 20 / 28 : loss = 0.451700121164Training loss: 0.449817687273
# Training acc: 0.979910714286
# Validation acc: 1.0
# Epoch 400
# 20 / 28 : loss = 0.452927321196Training loss: 0.466679185629
# Training acc: 0.966517857143
# Validation acc: 0.989583333333
# Testing acc: 0.45564516129
# Epoch 401
# Training loss: 0.49962228536676
# Training acc: 0.963169642857
# Validation acc: 0.989583333333
# Epoch 402
# Training loss: 0.54737943410951
# Training acc: 0.9453125
# Validation acc: 0.958333333333
# Epoch 403
# Training loss: 0.60573273897291
# Training acc: 0.918526785714
# Validation acc: 1.0
# Epoch 404
# Training loss: 0.55914413929407
# Training acc: 0.948660714286
# Validation acc: 0.958333333333
# Epoch 405
# 20 / 28 : loss = 0.562510013583Training loss: 0.553509771824
# Training acc: 0.952008928571
# Validation acc: 1.0
# Epoch 406
# Training loss: 0.51805603504218
# Training acc: 0.965401785714
# Validation acc: 0.989583333333
# Epoch 407
# Training loss: 0.50167411565895
# Training acc: 0.975446428571
# Validation acc: 0.989583333333
# Epoch 408
# Training loss: 0.47585773468759
# Training acc: 0.975446428571
# Validation acc: 0.989583333333
# Epoch 409
# 20 / 28 : loss = 0.486402153969Training loss: 0.480721563101
# Training acc: 0.972098214286
# Validation acc: 0.989583333333
# ...
# Epoch 348
# Training loss: 0.12421725690468
# Training acc: 0.9921875
# Validation acc: 0.979166666667
# Epoch 349
# Training loss: 0.11398565769214
# Training acc: 0.995535714286
# Validation acc: 0.96875
# Epoch 350
# Training loss: 0.12507437169672
# Training acc: 0.989955357143
# Validation acc: 0.958333333333
# Epoch 351
# Training loss: 0.12904299795624
# Training acc: 0.9921875
# Validation acc: 0.958333333333
# Epoch 352
# 20 / 28 : loss = 0.123658858244Training loss: 0.1229069978
# Training acc: 0.993303571429
# Validation acc: 0.989583333333
# Epoch 353
# Training loss: 0.14642716944237
# Training acc: 0.984375
# Validation acc: 1.0
# Epoch 354
# 20 / 28 : loss = 0.129590272903Training loss: 0.125716939569
# Training acc: 0.988839285714
# Validation acc: 1.0
# Epoch 355
# Training loss: 0.12342549115419
# Training acc: 0.991071428571
# Validation acc: 0.979166666667
# Epoch 356
# Training loss: 0.12124902755411
# Training acc: 0.993303571429
# Validation acc: 0.989583333333
# Epoch 357
# 20 / 28 : loss = 0.150041431189Training loss: 0.146147727966
# Training acc: 0.981026785714
# Validation acc: 1.0
# Epoch 358
# Training loss: 0.12824797630362
# Training acc: 0.988839285714
# Validation acc: 0.989583333333
# Epoch 359
# 20 / 28 : loss = 0.122887201607Training loss: 0.129846051335
# Training acc: 0.986607142857
# Validation acc: 1.0
# Epoch 360
# 20 / 28 : loss = 0.126190111041Training loss: 0.123180404305
# Training acc: 0.993303571429
# Validation acc: 1.0
# Testing acc: 0.975806451613
# Epoch 361
# Training loss: 0.11976360529738
# Training acc: 0.988839285714
# Validation acc: 1.0
# Epoch 362
# Training loss: 0.13850320875631
# Training acc: 0.982142857143
# Validation acc: 1.0
# Epoch 363
# Training loss: 0.11493545770621
# Training acc: 0.995535714286
# Validation acc: 0.989583333333
# Epoch 364
# Training loss: 0.12311411649115
# Training acc: 0.987723214286
# Validation acc: 0.989583333333
# Epoch 365
# 20 / 28 : loss = 0.120301485062Training loss: 0.119071654975
# Training acc: 0.995535714286
# Validation acc: 1.0
# Epoch 366
# 20 / 28 : loss = 0.123386099935Training loss: 0.126434251666
# Training acc: 0.988839285714
# Validation acc: 0.989583333333
# Epoch 367
# Training loss: 0.13092567026662
# Training acc: 0.983258928571
# Validation acc: 0.989583333333
# Epoch 368
# Training loss: 0.12272235006178
# Training acc: 0.994419642857
# Validation acc: 1.0
# Epoch 369
# Training loss: 0.12168952077634
# Training acc: 0.993303571429
# Validation acc: 0.979166666667
# Epoch 370
# Training loss: 0.11850787699231
# Training acc: 0.9921875
# Validation acc: 0.989583333333
# Epoch 371
# Training loss: 0.14464855194125
# Training acc: 0.982142857143
# Validation acc: 0.989583333333
# Epoch 372
# Training loss: 0.12370409071419
# Training acc: 0.995535714286
# Validation acc: 1.0
# Epoch 373
# 20 / 28 : loss = 0.126378893852Training loss: 0.129687696695
# Training acc: 0.988839285714
# Validation acc: 1.0
# Epoch 374
# Training loss: 0.11573142558326
# Training acc: 0.995535714286
# Validation acc: 0.979166666667
# Epoch 375
# Training loss: 0.12473701685736
# Training acc: 0.991071428571
# Validation acc: 1.0
# Epoch 376
# Training loss: 0.12030769884636
# Training acc: 0.993303571429
# Validation acc: 0.989583333333
# Epoch 377
# 20 / 28 : loss = 0.112962283194Training loss: 0.118268236518
# Training acc: 0.995535714286
# Validation acc: 1.0
# Epoch 378
# Training loss: 0.11939039081359
# Training acc: 0.991071428571
# Validation acc: 1.0
# Epoch 379
# Training loss: 0.11385123431744
# Training acc: 0.995535714286
# Validation acc: 0.96875
# Epoch 380
# Training loss: 0.12011139839916
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Testing acc: 0.973790322581
# Epoch 381
# Training loss: 0.12872339785151
# Training acc: 0.988839285714
# Validation acc: 1.0
# Epoch 382
# Training loss: 0.13576421141666
# Training acc: 0.985491071429
# Validation acc: 0.979166666667
# Epoch 383
# Training loss: 0.11478848755446
# Training acc: 0.997767857143
# Validation acc: 1.0
# Epoch 384
# Training loss: 0.11360476911182
# Training acc: 0.993303571429
# Validation acc: 0.989583333333
# Epoch 385
# Training loss: 0.12846517562946
# Training acc: 0.988839285714
# Validation acc: 0.958333333333
# Epoch 386
# Training loss: 0.13551571965225
# Training acc: 0.987723214286
# Validation acc: 0.989583333333
# Epoch 387
# Training loss: 0.11506050080117
# Training acc: 0.997767857143
# Validation acc: 0.989583333333
# Epoch 388
# Training loss: 0.12274134159104
# Training acc: 0.9921875
# Validation acc: 1.0
# Epoch 389
# Training loss: 0.12945032119842
# Training acc: 0.988839285714
# Validation acc: 1.0
# Epoch 390
# Training loss: 0.12002380937351
# Training acc: 0.9921875
# Validation acc: 1.0
# Epoch 391
# Training loss: 0.12307681888371
# Training acc: 0.9921875
# Validation acc: 1.0
# Epoch 392
# Training loss: 0.12372592836625
# Training acc: 0.988839285714
# Validation acc: 1.0
# Epoch 393
# Training loss: 0.13544736802614
# Training acc: 0.984375
# Validation acc: 1.0
# Epoch 394
# 20 / 28 : loss = 0.114172957838Training loss: 0.121209539473
# Training acc: 0.995535714286
# Validation acc: 0.979166666667
# Epoch 395
# Training loss: 0.11808299273363
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Epoch 396
# 20 / 28 : loss = 0.120522797108Training loss: 0.118964359164
# Training acc: 0.9921875
# Validation acc: 0.989583333333
# Epoch 397
# 20 / 28 : loss = 0.127217367291Training loss: 0.142953082919
# Training acc: 0.987723214286
# Validation acc: 0.958333333333
# Epoch 398
# 20 / 28 : loss = 0.134178370237Training loss: 0.13080906868
# Training acc: 0.988839285714
# Validation acc: 0.989583333333
# Epoch 399
# Training loss: 0.12157554924533
# Training acc: 0.9921875
# Validation acc: 0.989583333333
# Epoch 400
# Training loss: 0.12112364918606
# Training acc: 0.9921875
# Validation acc: 1.0
# Testing acc: 0.974798387097
# Epoch 401
# Training loss: 0.11782441288293
# Training acc: 0.9921875
# Validation acc: 0.989583333333
# Epoch 402
# Training loss: 0.12222778052149
# Training acc: 0.991071428571
# Validation acc: 0.989583333333
# Epoch 403
# Training loss: 0.14792732894418
# Training acc: 0.983258928571
# Validation acc: 1.0
# Epoch 404
# Training loss: 0.12468820065387
# Training acc: 0.993303571429
# Validation acc: 0.989583333333
# Epoch 405
# Training loss: 0.11871223896748
# Training acc: 0.996651785714
# Validation acc: 0.96875
# Epoch 406
# Training loss: 0.11677580326886
# Training acc: 0.993303571429
# Validation acc: 0.979166666667
# Epoch 407
# Training loss: 0.11480836570375
# Training acc: 0.995535714286
# Validation acc: 1.0
# Epoch 408
# Training loss: 0.11939211934826
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Epoch 409
# 20 / 28 : loss = 0.133015468717Training loss: 0.127881854773
# Training acc: 0.991071428571
# Validation acc: 0.979166666667
# Epoch 410
# Training loss: 0.11866391450275
# Training acc: 0.9921875
# Validation acc: 0.989583333333
# Epoch 411
# Training loss: 0.12580552697265
# Training acc: 0.991071428571
# Validation acc: 1.0
# Epoch 412
# 20 / 28 : loss = 0.124893821776Training loss: 0.127262160182
# Training acc: 0.989955357143
# Validation acc: 0.979166666667
# Epoch 413
# Training loss: 0.11689102649763
# Training acc: 0.9921875
# Validation acc: 1.0
# Epoch 414
# Training loss: 0.11281579732952
# Training acc: 0.995535714286
# Validation acc: 0.979166666667
# Epoch 415
# Training loss: 0.13451060652788
# Training acc: 0.984375
# Validation acc: 1.0
# Epoch 416
# Training loss: 0.12199391424729
# Training acc: 0.991071428571
# Validation acc: 1.0
# Epoch 417
# Training loss: 0.11313221603618
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Epoch 418
# Training loss: 0.13317795097816
# Training acc: 0.989955357143
# Validation acc: 1.0
# Epoch 419
# Training loss: 0.11535853892674
# Training acc: 0.994419642857
# Validation acc: 0.979166666667
# Epoch 420
# Training loss: 0.11285466700845
# Training acc: 0.994419642857
# Validation acc: 1.0
# Testing acc: 0.977822580645
# Epoch 421
# Training loss: 0.11265711486336
# Training acc: 0.995535714286
# Validation acc: 0.96875
# Epoch 422
# Training loss: 0.12070921808593
# Training acc: 0.989955357143
# Validation acc: 1.0
# Epoch 423
# Training loss: 0.12968444824239
# Training acc: 0.984375
# Validation acc: 0.989583333333
# Epoch 424
# 20 / 28 : loss = 0.112704209983Training loss: 0.115100376308
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Epoch 425
# Training loss: 0.13734160363736
# Training acc: 0.985491071429
# Validation acc: 0.958333333333
# Epoch 426
# Training loss: 0.12532047927417
# Training acc: 0.993303571429
# Validation acc: 1.0
# Epoch 427
# Training loss: 0.11499283462842
# Training acc: 0.995535714286
# Validation acc: 0.989583333333
# Epoch 428
# Training loss: 0.11571727693173
# Training acc: 0.993303571429
# Validation acc: 0.979166666667
# Epoch 429
# Training loss: 0.13296577334417
# Training acc: 0.984375
# Validation acc: 1.0
# Epoch 430
# Training loss: 0.12070654332626
# Training acc: 0.988839285714
# Validation acc: 1.0
# Epoch 431
# Training loss: 0.13788847625342
# Training acc: 0.988839285714
# Validation acc: 0.979166666667
# Epoch 432
# 20 / 28 : loss = 0.117959655821Training loss: 0.124232582748
# Training acc: 0.993303571429
# Validation acc: 0.989583333333
# Epoch 433
# Training loss: 0.13033029437158
# Training acc: 0.989955357143
# Validation acc: 1.0
# Epoch 434
# 20 / 28 : loss = 0.119730517268Training loss: 0.124223038554
# Training acc: 0.993303571429
# Validation acc: 1.0
# Epoch 435
# Training loss: 0.11930786073249
# Training acc: 0.993303571429
# Validation acc: 0.979166666667
# Epoch 436
# Training loss: 0.12580777704773
# Training acc: 0.989955357143
# Validation acc: 0.989583333333
# Epoch 437
# 20 / 28 : loss = 0.129443764687Training loss: 0.135475799441
# Training acc: 0.988839285714
# Validation acc: 0.989583333333
# Epoch 438
# 20 / 28 : loss = 0.112816832966Training loss: 0.114440366626
# Training acc: 0.995535714286
# Validation acc: 0.979166666667
# Epoch 439
# Training loss: 0.12857088446631
# Training acc: 0.9921875
# Validation acc: 0.979166666667
# Epoch 440
# 20 / 28 : loss = 0.117233261466Training loss: 0.123994581401
# Training acc: 0.994419642857
# Validation acc: 1.0
# Testing acc: 0.974798387097
# Epoch 441
# Training loss: 0.11418149620345
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Epoch 442
# Training loss: 0.12069545686253
# Training acc: 0.989955357143
# Validation acc: 1.0
# Epoch 443
# Training loss: 0.11610954999935
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Epoch 444
# Training loss: 0.12311854213558
# Training acc: 0.987723214286
# Validation acc: 1.0
# Epoch 445
# Training loss: 0.11833541095347
# Training acc: 0.9921875
# Validation acc: 0.989583333333
# Epoch 446
# Training loss: 0.11848697811418
# Training acc: 0.9921875
# Validation acc: 0.979166666667
# Epoch 447
# Training loss: 0.11294125765622
# Training acc: 0.995535714286
# Validation acc: 1.0
# Epoch 448
# Training loss: 0.11825634539109
# Training acc: 0.994419642857
# Validation acc: 1.0
# Epoch 449
# Training loss: 0.12530884146797
# Training acc: 0.9921875
# Validation acc: 0.989583333333
# Epoch 450
# 20 / 28 : loss = 0.118273645639Training loss: 0.118894644082
# Training acc: 0.991071428571
# Validation acc: 0.989583333333
# Epoch 451
# Training loss: 0.12839718163725
# Training acc: 0.988839285714
# Validation acc: 0.96875
# Epoch 452
# 20 / 28 : loss = 0.114464938641Training loss: 0.113332211971
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Epoch 453
# Training loss: 0.14186234772248
# Training acc: 0.984375
# Validation acc: 1.0
# Epoch 454
# 20 / 28 : loss = 0.131404891618Training loss: 0.140072420239
# Training acc: 0.987723214286
# Validation acc: 1.0
# Epoch 455
# 20 / 28 : loss = 0.124049939215Training loss: 0.122935585678
# Training acc: 0.991071428571
# Validation acc: 0.958333333333
# Epoch 456
# 20 / 28 : loss = 0.11075091362Training loss: 0.111188985407
# Training acc: 0.995535714286
# Validation acc: 1.0
# Epoch 457
# 20 / 28 : loss = 0.112121045589Training loss: 0.121287606657
# Training acc: 0.9921875
# Validation acc: 1.0
# Epoch 458
# 20 / 28 : loss = 0.111143603921Training loss: 0.111570321023
# Training acc: 0.996651785714
# Validation acc: 1.0
# Epoch 459
# 20 / 28 : loss = 0.111538387835Training loss: 0.112661227584
# Training acc: 0.996651785714
# Validation acc: 1.0
# Epoch 460
# Training loss: 0.11873149126806
# Training acc: 0.989955357143
# Validation acc: 1.0
# Testing acc: 0.973790322581
# Epoch 461
# Training loss: 0.11805762350631
# Training acc: 0.991071428571
# Validation acc: 0.96875
# Epoch 462
# Training loss: 0.12173678726697
# Training acc: 0.988839285714
# Validation acc: 1.0
# Epoch 463
# Training loss: 0.11701668798991
# Training acc: 0.991071428571
# Validation acc: 1.0
# Epoch 464
# Training loss: 0.12562133371831
# Training acc: 0.989955357143
# Validation acc: 0.96875
# Epoch 465
# Training loss: 0.12759268283888
# Training acc: 0.987723214286
# Validation acc: 0.989583333333
# Epoch 466
# Training loss: 0.11700539290913
# Training acc: 0.9921875
# Validation acc: 1.0
# Epoch 467
# Training loss: 0.11695768684133
# Training acc: 0.994419642857
# Validation acc: 0.979166666667
# Epoch 468
# Training loss: 0.11725610494659
# Training acc: 0.994419642857
# Validation acc: 1.0
# Epoch 469
# Training loss: 0.11345436424244
# Training acc: 0.995535714286
# Validation acc: 0.96875
# Epoch 470
# Training loss: 0.13318310678519
# Training acc: 0.984375
# Validation acc: 1.0
# Epoch 471
# 20 / 28 : loss = 0.139162659645Training loss: 0.131819233298
# Training acc: 0.986607142857
# Validation acc: 1.0
# Epoch 472
# 20 / 28 : loss = 0.141273096204Training loss: 0.135003820062
# Training acc: 0.989955357143
# Validation acc: 0.979166666667
# Epoch 473
# Training loss: 0.12694045901397
# Training acc: 0.989955357143
# Validation acc: 0.989583333333
# Epoch 474
# Training loss: 0.14817927777805
# Training acc: 0.983258928571
# Validation acc: 1.0
# Epoch 475
# Training loss: 0.1220037117642
# Training acc: 0.993303571429
# Validation acc: 1.0
# Epoch 476
# Training loss: 0.12787008285519
# Training acc: 0.987723214286
# Validation acc: 1.0
# Epoch 477
# 20 / 28 : loss = 0.123612426221Training loss: 0.120909444988
# Training acc: 0.991071428571
# Validation acc: 1.0
# Epoch 478
# 20 / 28 : loss = 0.112083241343Training loss: 0.116020679474
# Training acc: 0.995535714286
# Validation acc: 0.989583333333
# Epoch 479
# Training loss: 0.11730758100724
# Training acc: 0.995535714286
# Validation acc: 0.989583333333
# Epoch 480
# 20 / 28 : loss = 0.112360365689Training loss: 0.111506566405
# Training acc: 0.996651785714
# Validation acc: 0.96875
# Testing acc: 0.970766129032
# Epoch 481
# Training loss: 0.13209697604216
# Training acc: 0.986607142857
# Validation acc: 0.989583333333
# Epoch 482
# Training loss: 0.11614572256842
# Training acc: 0.994419642857
# Validation acc: 0.979166666667
# Epoch 483
# Training loss: 0.11679600179265
# Training acc: 0.9921875
# Validation acc: 1.0
# Epoch 484
# Training loss: 0.12079522758721
# Training acc: 0.988839285714
# Validation acc: 0.989583333333
# Epoch 485
# Training loss: 0.11672993749422
# Training acc: 0.993303571429
# Validation acc: 0.989583333333
# Epoch 486
# Training loss: 0.11291491985338
# Training acc: 0.993303571429
# Validation acc: 1.0
# Epoch 487
# Training loss: 0.12192606180929
# Training acc: 0.9921875
# Validation acc: 0.979166666667
# Epoch 488
# Training loss: 0.12000887841994
# Training acc: 0.9921875
# Validation acc: 1.0
# Epoch 489
# Training loss: 0.11571334302487
# Training acc: 0.995535714286
# Validation acc: 1.0
# Epoch 490
# 20 / 28 : loss = 0.138285800815Training loss: 0.131569489837
# Training acc: 0.987723214286
# Validation acc: 0.989583333333
# Epoch 491
# 20 / 28 : loss = 0.120466314256Training loss: 0.118639193475
# Training acc: 0.994419642857
# Validation acc: 0.989583333333
# Epoch 492
# 20 / 28 : loss = 0.117620773613Training loss: 0.122422456741
# Training acc: 0.991071428571
# Validation acc: 0.989583333333
# Epoch 493
# 20 / 28 : loss = 0.116632781923Training loss: 0.117229327559
# Training acc: 0.995535714286
# Validation acc: 0.96875
# Epoch 494
# 20 / 28 : loss = 0.114721059799Training loss: 0.118088841438
# Training acc: 0.993303571429
# Validation acc: 1.0
# Epoch 495
# 20 / 28 : loss = 0.117450341582Training loss: 0.130160182714
# Training acc: 0.987723214286
# Validation acc: 0.979166666667
# Epoch 496
# Training loss: 0.12324742972905
# Training acc: 0.991071428571
# Validation acc: 1.0
# Epoch 497
# 20 / 28 : loss = 0.116105377674Training loss: 0.118150569499
# Training acc: 0.9921875
# Validation acc: 0.979166666667
# Epoch 498
# 20 / 28 : loss = 0.121244631708Training loss: 0.12333881855
# Training acc: 0.989955357143
# Validation acc: 1.0
# Epoch 499
# 20 / 28 : loss = 0.113033466041Training loss: 0.110718235373
# Training acc: 0.998883928571
# Validation acc: 0.989583333333
